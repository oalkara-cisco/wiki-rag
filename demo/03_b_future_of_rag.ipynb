# %% [markdown]
# ## Future of RAG
#
# ### LLM context windows
#
# ##### 5000 tokens ~ dozens of pages text
# ##### 1000,000 tokens ~ 2500 pages of text
#
# | Year | Model | Context Window Size |
# |------|-------|---------------------|
# | **2018** | GPT-1 | ~500 tokens |
# | **2018** | BERT | 512 tokens |
# | **2019** | GPT-2 | 1,024 tokens |
# | **2020** | GPT-3 | 2,048 tokens |
# | **2021** | Jurassic-1 | 2,048 tokens |
# | **2021** | LaMDA | ~8,000 tokens |
# | **2022** | GPT-NeoX | 2,048 tokens |
# | **2022** | PaLM | 8,192 tokens |
# | **2022** | Chinchilla | 2,048 tokens |
# | **2022** | Claude 1 | ~9,000 tokens |
# | **2023 (Mar)** | GPT-4 (initial) | 8,192 tokens |
# | **2023** | GPT-4 (later) | 32,768 tokens |
# | **2023 (Jul)** | Claude 2 | 100,000 tokens |
# | **2023 (Jul)** | Llama 2 | 4,096 tokens |
# | **2023 (Oct)** | Claude Instant | 100,000 tokens |
# | **2023 (Nov)** | Claude 2.1 | 200,000 tokens |
# | **2024 (Mar)** | Claude 3 Family | Up to 200,000 tokens |
# | **2024 (May)** | GPT-4o | 128,000 tokens |
# | **2024 (Jul)** | Claude 3.5 Sonnet | 200,000 tokens |
# | **2024 (Oct)** | Gemini 2.0 | 1,000,000+ tokens |
#
# <div>
# <img src="attachment:b23c7a16-6759-4be4-9de2-7105a6c064a7.png" width="900"/>
# </div>
